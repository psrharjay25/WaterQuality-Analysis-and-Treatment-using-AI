# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ## Begin

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# basic libraries and machine learning library scikit learn

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler

# %%
# import, file format

# %%
df = pd.read_csv("/content/drive/MyDrive/AI_Project/Pond Dataset 2021.csv", encoding='iso-8859-1')

# %%
df
# Out:
#      STN\nCode                        Name of Monitoring Location  \
# 0       4368.0      KOLLERU LAKE KOKKIRAYALANKA (V), KAILALUR (M)
# 1       2353.0  KONDAKARLA-AAVA LAKE, PARAWADA PHARMA CITY, VI...
# 2       1790.0                       PULICATE LAKE , NELLORE DIST
# 3       4391.0      CHENGAMBAKAM TANK IN SRI CITY SEZ,\nTIRUPATHI
# 4       4921.0           ANNAMAYYA PROJECT ON CHEYYERU\nRESERVOIR
# ..         ...                                                ...
# 615     1765.0  RABINDRASAROVAR NATIONAL LAKE,\nCALCUTTA, WEST...
# 616     2544.0                              SAHEBBANDH AT PURULIA
# 617     2522.0                        SINCHAL LAKE FOR DARJEELING
# 618     2521.0          WATER RESERVIOR AT DELO LAKE,\nDARJELLING
# 619     4725.0                  WATER RESERVIOR ST. HELENS SCHOOL
#
#     Type Water Body      State Name  Temperature\n?C (Min)  \
# 0              LAKE  ANDHRA PRADESH                   24.0
# 1              LAKE  ANDHRA PRADESH                   26.0
# 2              LAKE  ANDHRA PRADESH                   18.0
# 3              TANK  ANDHRA PRADESH                   22.0
# 4           Wetland  ANDHRA PRADESH                   21.0
# ..              ...             ...                    ...
# 615            LAKE     WEST BENGAL                   22.0
# 616            LAKE     WEST BENGAL                   22.0
# 617            LAKE     WEST BENGAL                    7.0
# 618            LAKE     WEST BENGAL                    9.0
# 619            LAKE     WEST BENGAL                    8.0
#
#      Temperature\n?C (Max) Dissolved Oxygen (mg/L) (Min)  \
# 0                     27.0                           3.2
# 1                     29.0                           3.0
# 2                     24.0                           4.2
# 3                     29.0                           5.4
# 4                     30.0                           5.4
# ..                     ...                           ...
# 615                   31.0                           5.2
# 616                   32.0                           8.8
# 617                   16.0                           7.1
# 618                   24.0                           7.2
# 619                   18.0                           7.1
#
#     Dissolved Oxygen (mg/L) (Max) pH (Min)  pH (Max)  \
# 0                             6.5      7.0       8.0
# 1                             6.8      6.9       7.8
# 2                             6.0      7.2       8.2
# 3                             6.2      6.3       7.9
# 4                             6.5      7.3       8.0
# ..                            ...      ...       ...
# 615                           9.7      7.2       8.5
# 616                           9.8      7.0       7.6
# 617                           8.1      6.9       7.6
# 618                           8.2      6.9       7.6
# 619                           8.5      6.9       7.9
#
#     Conductivity (?mhos/cm) (Min) Conductivity (?mhos/cm) (Max)  \
# 0                             245                          5160
# 1                             599                          1179
# 2                           28000                         56900
# 3                             180                           476
# 4                             496                           734
# ..                            ...                           ...
# 615                           252                           826
# 616                           311                           422
# 617                            13                            29
# 618                            20                            36
# 619                            16                            73
#
#     BOD (mg/L) (Min) BOD (mg/L) (Max) Nitrate N + Nitrite N(mg/L) (Min)  \
# 0                1.6              3.2                              1.02
# 1                1.9              4.6                              0.77
# 2                2.4              2.8                              1.20
# 3                1.0              2.5                              0.34
# 4                1.0              2.3                              0.35
# ..               ...              ...                               ...
# 615              1.8              4.1                              0.30
# 616              2.7              7.3                              0.30
# 617              1.0              1.1                              0.30
# 618              1.0              1.8                              0.30
# 619              1.0              1.6                              0.30
#
#     Nitrate N + Nitrite N(mg/L) (Max) Fecal Coliform (MPN/100ml) (Min)  \
# 0                                3.60                                9
# 1                                3.56                               15
# 2                                1.64                                3
# 3                                2.30                               24
# 4                                1.00                               43
# ..                                ...                              ...
# 615                              1.90                              330
# 616                              0.80                             3100
# 617                              0.30                               70
# 618                              0.30                               60
# 619                              0.30                               70
#
#     Fecal Coliform (MPN/100ml) (Max) Total Coliform (MPN/100ml) (Min)  \
# 0                                 21                              120
# 1                                 23                              150
# 2                                  3                               47
# 3                                365                              170
# 4                                289                              240
# ..                               ...                              ...
# 615                              790                             1100
# 616                             9400                             4300
# 617                              110                              110
# 618                              130                              110
# 619                              110                              110
#
#     Total Coliform (MPN/100ml) (Max)
# 0                                210
# 1                                240
# 2                                150
# 3                                549
# 4                                727
# ..                               ...
# 615                             1700
# 616                            12000
# 617                              210
# 618                              330
# 619                              330
#
# [620 rows x 20 columns]

# %%
print(set(df["State Name"]))
# Out:
# {'TRIPURA', 'RAJASTHAN', 'MANIPUR', 'NAGALAND', 'UTTARAKHAND', 'MADHYA PRADESH', 'HIMACHAL\nPRADESH', 'JAMMU & KASHMIR', 'KARNATAKA', 'MADHYA\nPRADESH', 'GOA', 'ASSAM', 'BIHAR', 'HARYANA', 'WEST BENGAL', 'ODISHA', 'CHHATTISGARH', 'GUJARAT', 'ANDHRA PRADESH', 'MIZORAM', 'MEGHALAYA', 'DELHI', 'LAKSHADWEEP', 'TELANGANA', 'PUNJAB', 'UTTAR PRADESH', 'TAMIL NADU', 'JHARKHAND', 'JAMMU &\nKASHMIR', 'KERALA', 'PUDUCHERRY', 'CHANDIGARH'}

# %%
df.groupby('State Name')

# %%
df.drop(columns=['Name of Monitoring Location'], inplace=True)

# %%
df.drop(columns=['STN\nCode'], inplace=True)

# %% [markdown]
# ## used Label encoder here

# %%
Water_Body = df['Type Water Body'].values
State = df['State Name'].values

# %%
encoder = LabelEncoder()
df['Type Water Body']= encoder.fit_transform(Water_Body)
df['State Name'] =  encoder.fit_transform(State)

# %%
df
# Out:
#      Type Water Body  State Name  Temperature\n?C (Min)  \
# 0                  0           0                   24.0
# 1                  0           0                   26.0
# 2                  0           0                   18.0
# 3                  2           0                   22.0
# 4                  3           0                   21.0
# ..               ...         ...                    ...
# 615                0          31                   22.0
# 616                0          31                   22.0
# 617                0          31                    7.0
# 618                0          31                    9.0
# 619                0          31                    8.0
#
#      Temperature\n?C (Max) Dissolved Oxygen (mg/L) (Min)  \
# 0                     27.0                           3.2
# 1                     29.0                           3.0
# 2                     24.0                           4.2
# 3                     29.0                           5.4
# 4                     30.0                           5.4
# ..                     ...                           ...
# 615                   31.0                           5.2
# 616                   32.0                           8.8
# 617                   16.0                           7.1
# 618                   24.0                           7.2
# 619                   18.0                           7.1
#
#     Dissolved Oxygen (mg/L) (Max) pH (Min)  pH (Max)  \
# 0                             6.5      7.0       8.0
# 1                             6.8      6.9       7.8
# 2                             6.0      7.2       8.2
# 3                             6.2      6.3       7.9
# 4                             6.5      7.3       8.0
# ..                            ...      ...       ...
# 615                           9.7      7.2       8.5
# 616                           9.8      7.0       7.6
# 617                           8.1      6.9       7.6
# 618                           8.2      6.9       7.6
# 619                           8.5      6.9       7.9
#
#     Conductivity (?mhos/cm) (Min) Conductivity (?mhos/cm) (Max)  \
# 0                             245                          5160
# 1                             599                          1179
# 2                           28000                         56900
# 3                             180                           476
# 4                             496                           734
# ..                            ...                           ...
# 615                           252                           826
# 616                           311                           422
# 617                            13                            29
# 618                            20                            36
# 619                            16                            73
#
#     BOD (mg/L) (Min) BOD (mg/L) (Max) Nitrate N + Nitrite N(mg/L) (Min)  \
# 0                1.6              3.2                              1.02
# 1                1.9              4.6                              0.77
# 2                2.4              2.8                              1.20
# 3                1.0              2.5                              0.34
# 4                1.0              2.3                              0.35
# ..               ...              ...                               ...
# 615              1.8              4.1                              0.30
# 616              2.7              7.3                              0.30
# 617              1.0              1.1                              0.30
# 618              1.0              1.8                              0.30
# 619              1.0              1.6                              0.30
#
#     Nitrate N + Nitrite N(mg/L) (Max) Fecal Coliform (MPN/100ml) (Min)  \
# 0                                3.60                                9
# 1                                3.56                               15
# 2                                1.64                                3
# 3                                2.30                               24
# 4                                1.00                               43
# ..                                ...                              ...
# 615                              1.90                              330
# 616                              0.80                             3100
# 617                              0.30                               70
# 618                              0.30                               60
# 619                              0.30                               70
#
#     Fecal Coliform (MPN/100ml) (Max) Total Coliform (MPN/100ml) (Min)  \
# 0                                 21                              120
# 1                                 23                              150
# 2                                  3                               47
# 3                                365                              170
# 4                                289                              240
# ..                               ...                              ...
# 615                              790                             1100
# 616                             9400                             4300
# 617                              110                              110
# 618                              130                              110
# 619                              110                              110
#
#     Total Coliform (MPN/100ml) (Max)
# 0                                210
# 1                                240
# 2                                150
# 3                                549
# 4                                727
# ..                               ...
# 615                             1700
# 616                            12000
# 617                              210
# 618                              330
# 619                              330
#
# [620 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Type Water Body                    620 non-null    int64
#  1   State Name                         620 non-null    int64
#  2   Temperature
# ?C (Min)               617 non-null    float64
#  3   Temperature
# ?C (Max)               617 non-null    float64
#  4   Dissolved Oxygen (mg/L) (Min)      620 non-null    object
#  5   Dissolved Oxygen (mg/L) (Max)      620 non-null    object
#  6   pH (Min)                           620 non-null    object
#  7   pH (Max)                           620 non-null    float64
#  8   Conductivity (?mhos/cm) (Min)      618 non-null    object
#  9   Conductivity (?mhos/cm) (Max)      618 non-null    object
#  10  BOD (mg/L) (Min)                   620 non-null    object
#  11  BOD (mg/L) (Max)                   620 non-null    object
#  12  Nitrate N + Nitrite N(mg/L) (Min)  620 non-null    object
#  13  Nitrate N + Nitrite N(mg/L) (Max)  620 non-null    object
#  14  Fecal Coliform (MPN/100ml) (Min)   619 non-null    object
#  15  Fecal Coliform (MPN/100ml) (Max)   619 non-null    object
#  16  Total Coliform (MPN/100ml) (Min)   619 non-null    object
#  17  Total Coliform (MPN/100ml) (Max)   619 non-null    object
# dtypes: float64(3), int64(2), object(13)
# memory usage: 87.3+ KB

# %%
df.nunique()
# Out:
# Type Water Body                        4
# State Name                            32
# Temperature\n?C (Min)                 59
# Temperature\n?C (Max)                 53
# Dissolved Oxygen (mg/L) (Min)         79
# Dissolved Oxygen (mg/L) (Max)        107
# pH (Min)                              31
# pH (Max)                              30
# Conductivity (?mhos/cm) (Min)        443
# Conductivity (?mhos/cm) (Max)        509
# BOD (mg/L) (Min)                      63
# BOD (mg/L) (Max)                     135
# Nitrate N + Nitrite N(mg/L) (Min)    147
# Nitrate N + Nitrite N(mg/L) (Max)    287
# Fecal Coliform (MPN/100ml) (Min)     115
# Fecal Coliform (MPN/100ml) (Max)     186
# Total Coliform (MPN/100ml) (Min)     137
# Total Coliform (MPN/100ml) (Max)     149
# dtype: int64

# %%
df.dtypes
# Out:
# Type Water Body                        int64
# State Name                             int64
# Temperature\n?C (Min)                float64
# Temperature\n?C (Max)                float64
# Dissolved Oxygen (mg/L) (Min)         object
# Dissolved Oxygen (mg/L) (Max)         object
# pH (Min)                              object
# pH (Max)                             float64
# Conductivity (?mhos/cm) (Min)         object
# Conductivity (?mhos/cm) (Max)         object
# BOD (mg/L) (Min)                      object
# BOD (mg/L) (Max)                      object
# Nitrate N + Nitrite N(mg/L) (Min)     object
# Nitrate N + Nitrite N(mg/L) (Max)     object
# Fecal Coliform (MPN/100ml) (Min)      object
# Fecal Coliform (MPN/100ml) (Max)      object
# Total Coliform (MPN/100ml) (Min)      object
# Total Coliform (MPN/100ml) (Max)      object
# dtype: object

# %%
df.to_csv("0.csv")

# %% [markdown]
# ## For all the blank spaces fill them with mean of that column

# %%
df.replace("-", np.nan, inplace=True)

# %%
df.to_csv("1.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Type Water Body                    620 non-null    int64
#  1   State Name                         620 non-null    int64
#  2   Temperature
# ?C (Min)               617 non-null    float64
#  3   Temperature
# ?C (Max)               617 non-null    float64
#  4   Dissolved Oxygen (mg/L) (Min)      618 non-null    object
#  5   Dissolved Oxygen (mg/L) (Max)      618 non-null    object
#  6   pH (Min)                           620 non-null    object
#  7   pH (Max)                           620 non-null    float64
#  8   Conductivity (?mhos/cm) (Min)      615 non-null    object
#  9   Conductivity (?mhos/cm) (Max)      615 non-null    object
#  10  BOD (mg/L) (Min)                   618 non-null    object
#  11  BOD (mg/L) (Max)                   618 non-null    object
#  12  Nitrate N + Nitrite N(mg/L) (Min)  568 non-null    object
#  13  Nitrate N + Nitrite N(mg/L) (Max)  568 non-null    object
#  14  Fecal Coliform (MPN/100ml) (Min)   568 non-null    object
#  15  Fecal Coliform (MPN/100ml) (Max)   568 non-null    object
#  16  Total Coliform (MPN/100ml) (Min)   568 non-null    object
#  17  Total Coliform (MPN/100ml) (Max)   568 non-null    object
# dtypes: float64(3), int64(2), object(13)
# memory usage: 87.3+ KB

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        try:
            # Convert to numeric if possible
            df[col] = pd.to_numeric(df[col], errors='coerce')

            # Fill missing values with the mode
            mode_value = df[col].mode().iloc[0]
            df[col].fillna(mode_value, inplace=True)
        except Exception as e:
            print(f"Error handling column {col}: {e}")

# If you want to handle numeric columns as well:
df.fillna(df.mean(), inplace=True)

# %%
for i in df.columns:
  if df[i].dtype=='object':
    try:
      df[i].fillna(df[i].mode(), inplace=True)
    except:
      print(i, "Not Done")

# %%
for i in df.columns:
    if df[i].dtype=='object':
        print(df[i])
        x=0
        try:
            print(x)
            df[i].fillna(df[i].mode(), inplace=True)
            x+=1
        except:
            print(i, "Not Done")
            x+=1

# %%
df.to_csv("2.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Type Water Body                    620 non-null    int64
#  1   State Name                         620 non-null    int64
#  2   Temperature
# ?C (Min)               620 non-null    float64
#  3   Temperature
# ?C (Max)               620 non-null    float64
#  4   Dissolved Oxygen (mg/L) (Min)      620 non-null    float64
#  5   Dissolved Oxygen (mg/L) (Max)      620 non-null    float64
#  6   pH (Min)                           620 non-null    float64
#  7   pH (Max)                           620 non-null    float64
#  8   Conductivity (?mhos/cm) (Min)      620 non-null    float64
#  9   Conductivity (?mhos/cm) (Max)      620 non-null    float64
#  10  BOD (mg/L) (Min)                   620 non-null    float64
#  11  BOD (mg/L) (Max)                   620 non-null    float64
#  12  Nitrate N + Nitrite N(mg/L) (Min)  620 non-null    float64
#  13  Nitrate N + Nitrite N(mg/L) (Max)  620 non-null    float64
#  14  Fecal Coliform (MPN/100ml) (Min)   620 non-null    float64
#  15  Fecal Coliform (MPN/100ml) (Max)   620 non-null    float64
#  16  Total Coliform (MPN/100ml) (Min)   620 non-null    float64
#  17  Total Coliform (MPN/100ml) (Max)   620 non-null    float64
# dtypes: float64(16), int64(2)
# memory usage: 87.3 KB

# %%
# no one is object type now

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Type Water Body, State Name, Temperature
# ?C (Min), Temperature
# ?C (Max), Dissolved Oxygen (mg/L) (Min), Dissolved Oxygen (mg/L) (Max), pH (Min), pH (Max), Conductivity (?mhos/cm) (Min), Conductivity (?mhos/cm) (Max), BOD (mg/L) (Min), BOD (mg/L) (Max), Nitrate N + Nitrite N(mg/L) (Min), Nitrate N + Nitrite N(mg/L) (Max), Fecal Coliform (MPN/100ml) (Min), Fecal Coliform (MPN/100ml) (Max), Total Coliform (MPN/100ml) (Min), Total Coliform (MPN/100ml) (Max)]
# Index: []

# %% [markdown]
# #### now no values are `NaN`, so we are good to go for model implementation

# %% [markdown]
# ## Final Graphs:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# LSTM
# BILSTM

# %%
df.corr()
# Out:
#                                    Type Water Body  State Name  \
# Type Water Body                           1.000000   -0.203781
# State Name                               -0.203781    1.000000
# Temperature\n?C (Min)                     0.191081    0.018169
# Temperature\n?C (Max)                    -0.074185    0.050481
# Dissolved Oxygen (mg/L) (Min)             0.057823   -0.137518
# Dissolved Oxygen (mg/L) (Max)             0.009569   -0.343606
# pH (Min)                                 -0.027018    0.056983
# pH (Max)                                 -0.069424    0.106491
# Conductivity (?mhos/cm) (Min)             0.085016   -0.057353
# Conductivity (?mhos/cm) (Max)             0.137627   -0.104230
# BOD (mg/L) (Min)                         -0.027450   -0.021093
# BOD (mg/L) (Max)                          0.029079   -0.036222
# Nitrate N + Nitrite N(mg/L) (Min)         0.085851    0.334484
# Nitrate N + Nitrite N(mg/L) (Max)        -0.012219    0.212607
# Fecal Coliform (MPN/100ml) (Min)          0.003708   -0.089325
# Fecal Coliform (MPN/100ml) (Max)         -0.048892   -0.025077
# Total Coliform (MPN/100ml) (Min)         -0.029232   -0.054553
# Total Coliform (MPN/100ml) (Max)         -0.037417   -0.022723
#
#                                    Temperature\n?C (Min)  \
# Type Water Body                                 0.191081
# State Name                                      0.018169
# Temperature\n?C (Min)                           1.000000
# Temperature\n?C (Max)                           0.200801
# Dissolved Oxygen (mg/L) (Min)                  -0.326656
# Dissolved Oxygen (mg/L) (Max)                  -0.262334
# pH (Min)                                       -0.134841
# pH (Max)                                        0.079681
# Conductivity (?mhos/cm) (Min)                   0.090154
# Conductivity (?mhos/cm) (Max)                   0.081248
# BOD (mg/L) (Min)                                0.228588
# BOD (mg/L) (Max)                                0.204605
# Nitrate N + Nitrite N(mg/L) (Min)               0.094020
# Nitrate N + Nitrite N(mg/L) (Max)               0.109300
# Fecal Coliform (MPN/100ml) (Min)                0.183479
# Fecal Coliform (MPN/100ml) (Max)                0.049225
# Total Coliform (MPN/100ml) (Min)                0.089061
# Total Coliform (MPN/100ml) (Max)                0.044436
#
#                                    Temperature\n?C (Max)  \
# Type Water Body                                -0.074185
# State Name                                      0.050481
# Temperature\n?C (Min)                           0.200801
# Temperature\n?C (Max)                           1.000000
# Dissolved Oxygen (mg/L) (Min)                  -0.067188
# Dissolved Oxygen (mg/L) (Max)                  -0.008248
# pH (Min)                                        0.106520
# pH (Max)                                        0.227596
# Conductivity (?mhos/cm) (Min)                  -0.019851
# Conductivity (?mhos/cm) (Max)                   0.066840
# BOD (mg/L) (Min)                                0.033069
# BOD (mg/L) (Max)                               -0.145886
# Nitrate N + Nitrite N(mg/L) (Min)              -0.015061
# Nitrate N + Nitrite N(mg/L) (Max)               0.024228
# Fecal Coliform (MPN/100ml) (Min)               -0.159246
# Fecal Coliform (MPN/100ml) (Max)               -0.060619
# Total Coliform (MPN/100ml) (Min)                0.031308
# Total Coliform (MPN/100ml) (Max)               -0.057883
#
#                                    Dissolved Oxygen (mg/L) (Min)  \
# Type Water Body                                         0.057823
# State Name                                             -0.137518
# Temperature\n?C (Min)                                  -0.326656
# Temperature\n?C (Max)                                  -0.067188
# Dissolved Oxygen (mg/L) (Min)                           1.000000
# Dissolved Oxygen (mg/L) (Max)                           0.544015
# pH (Min)                                                0.153305
# pH (Max)                                               -0.077471
# Conductivity (?mhos/cm) (Min)                          -0.057574
# Conductivity (?mhos/cm) (Max)                          -0.036238
# BOD (mg/L) (Min)                                       -0.367128
# BOD (mg/L) (Max)                                       -0.416501
# Nitrate N + Nitrite N(mg/L) (Min)                      -0.209874
# Nitrate N + Nitrite N(mg/L) (Max)                      -0.282295
# Fecal Coliform (MPN/100ml) (Min)                       -0.155917
# Fecal Coliform (MPN/100ml) (Max)                       -0.107223
# Total Coliform (MPN/100ml) (Min)                       -0.066294
# Total Coliform (MPN/100ml) (Max)                       -0.094095
#
#                                    Dissolved Oxygen (mg/L) (Max)  pH (Min)  \
# Type Water Body                                         0.009569 -0.027018
# State Name                                             -0.343606  0.056983
# Temperature\n?C (Min)                                  -0.262334 -0.134841
# Temperature\n?C (Max)                                  -0.008248  0.106520
# Dissolved Oxygen (mg/L) (Min)                           0.544015  0.153305
# Dissolved Oxygen (mg/L) (Max)                           1.000000  0.073944
# pH (Min)                                                0.073944  1.000000
# pH (Max)                                                0.119009  0.495685
# Conductivity (?mhos/cm) (Min)                          -0.114870  0.037599
# Conductivity (?mhos/cm) (Max)                           0.011067 -0.013797
# BOD (mg/L) (Min)                                       -0.224471  0.116948
# BOD (mg/L) (Max)                                       -0.139762 -0.165761
# Nitrate N + Nitrite N(mg/L) (Min)                      -0.329912 -0.025548
# Nitrate N + Nitrite N(mg/L) (Max)                      -0.237161 -0.038977
# Fecal Coliform (MPN/100ml) (Min)                       -0.018558 -0.104378
# Fecal Coliform (MPN/100ml) (Max)                       -0.058619 -0.086923
# Total Coliform (MPN/100ml) (Min)                       -0.078733  0.042028
# Total Coliform (MPN/100ml) (Max)                       -0.070426 -0.072659
#
#                                    pH (Max)  Conductivity (?mhos/cm) (Min)  \
# Type Water Body                   -0.069424                       0.085016
# State Name                         0.106491                      -0.057353
# Temperature\n?C (Min)              0.079681                       0.090154
# Temperature\n?C (Max)              0.227596                      -0.019851
# Dissolved Oxygen (mg/L) (Min)     -0.077471                      -0.057574
# Dissolved Oxygen (mg/L) (Max)      0.119009                      -0.114870
# pH (Min)                           0.495685                       0.037599
# pH (Max)                           1.000000                       0.039460
# Conductivity (?mhos/cm) (Min)      0.039460                       1.000000
# Conductivity (?mhos/cm) (Max)      0.090239                       0.584005
# BOD (mg/L) (Min)                   0.034745                       0.112564
# BOD (mg/L) (Max)                  -0.075134                       0.051589
# Nitrate N + Nitrite N(mg/L) (Min) -0.098127                       0.123924
# Nitrate N + Nitrite N(mg/L) (Max)  0.041053                       0.043903
# Fecal Coliform (MPN/100ml) (Min)  -0.013623                       0.060027
# Fecal Coliform (MPN/100ml) (Max)  -0.092993                       0.009387
# Total Coliform (MPN/100ml) (Min)   0.002174                       0.122946
# Total Coliform (MPN/100ml) (Max)  -0.111075                       0.008781
#
#                                    Conductivity (?mhos/cm) (Max)  \
# Type Water Body                                         0.137627
# State Name                                             -0.104230
# Temperature\n?C (Min)                                   0.081248
# Temperature\n?C (Max)                                   0.066840
# Dissolved Oxygen (mg/L) (Min)                          -0.036238
# Dissolved Oxygen (mg/L) (Max)                           0.011067
# pH (Min)                                               -0.013797
# pH (Max)                                                0.090239
# Conductivity (?mhos/cm) (Min)                           0.584005
# Conductivity (?mhos/cm) (Max)                           1.000000
# BOD (mg/L) (Min)                                        0.008738
# BOD (mg/L) (Max)                                        0.044621
# Nitrate N + Nitrite N(mg/L) (Min)                       0.053111
# Nitrate N + Nitrite N(mg/L) (Max)                       0.009871
# Fecal Coliform (MPN/100ml) (Min)                       -0.007115
# Fecal Coliform (MPN/100ml) (Max)                       -0.005284
# Total Coliform (MPN/100ml) (Min)                        0.026492
# Total Coliform (MPN/100ml) (Max)                       -0.006043
#
#                                    BOD (mg/L) (Min)  BOD (mg/L) (Max)  \
# Type Water Body                           -0.027450          0.029079
# State Name                                -0.021093         -0.036222
# Temperature\n?C (Min)                      0.228588          0.204605
# Temperature\n?C (Max)                      0.033069         -0.145886
# Dissolved Oxygen (mg/L) (Min)             -0.367128         -0.416501
# Dissolved Oxygen (mg/L) (Max)             -0.224471         -0.139762
# pH (Min)                                   0.116948         -0.165761
# pH (Max)                                   0.034745         -0.075134
# Conductivity (?mhos/cm) (Min)              0.112564          0.051589
# Conductivity (?mhos/cm) (Max)              0.008738          0.044621
# BOD (mg/L) (Min)                           1.000000          0.472205
# BOD (mg/L) (Max)                           0.472205          1.000000
# Nitrate N + Nitrite N(mg/L) (Min)          0.284797          0.235372
# Nitrate N + Nitrite N(mg/L) (Max)          0.109462          0.136084
# Fecal Coliform (MPN/100ml) (Min)           0.343314          0.242318
# Fecal Coliform (MPN/100ml) (Max)           0.119305          0.456579
# Total Coliform (MPN/100ml) (Min)           0.368641          0.063050
# Total Coliform (MPN/100ml) (Max)           0.161723          0.246964
#
#                                    Nitrate N + Nitrite N(mg/L) (Min)  \
# Type Water Body                                             0.085851
# State Name                                                  0.334484
# Temperature\n?C (Min)                                       0.094020
# Temperature\n?C (Max)                                      -0.015061
# Dissolved Oxygen (mg/L) (Min)                              -0.209874
# Dissolved Oxygen (mg/L) (Max)                              -0.329912
# pH (Min)                                                   -0.025548
# pH (Max)                                                   -0.098127
# Conductivity (?mhos/cm) (Min)                               0.123924
# Conductivity (?mhos/cm) (Max)                               0.053111
# BOD (mg/L) (Min)                                            0.284797
# BOD (mg/L) (Max)                                            0.235372
# Nitrate N + Nitrite N(mg/L) (Min)                           1.000000
# Nitrate N + Nitrite N(mg/L) (Max)                           0.325853
# Fecal Coliform (MPN/100ml) (Min)                           -0.070981
# Fecal Coliform (MPN/100ml) (Max)                           -0.002319
# Total Coliform (MPN/100ml) (Min)                           -0.004118
# Total Coliform (MPN/100ml) (Max)                           -0.003265
#
#                                    Nitrate N + Nitrite N(mg/L) (Max)  \
# Type Water Body                                            -0.012219
# State Name                                                  0.212607
# Temperature\n?C (Min)                                       0.109300
# Temperature\n?C (Max)                                       0.024228
# Dissolved Oxygen (mg/L) (Min)                              -0.282295
# Dissolved Oxygen (mg/L) (Max)                              -0.237161
# pH (Min)                                                   -0.038977
# pH (Max)                                                    0.041053
# Conductivity (?mhos/cm) (Min)                               0.043903
# Conductivity (?mhos/cm) (Max)                               0.009871
# BOD (mg/L) (Min)                                            0.109462
# BOD (mg/L) (Max)                                            0.136084
# Nitrate N + Nitrite N(mg/L) (Min)                           0.325853
# Nitrate N + Nitrite N(mg/L) (Max)                           1.000000
# Fecal Coliform (MPN/100ml) (Min)                           -0.001362
# Fecal Coliform (MPN/100ml) (Max)                            0.020658
# Total Coliform (MPN/100ml) (Min)                           -0.009350
# Total Coliform (MPN/100ml) (Max)                            0.005867
#
#                                    Fecal Coliform (MPN/100ml) (Min)  \
# Type Water Body                                            0.003708
# State Name                                                -0.089325
# Temperature\n?C (Min)                                      0.183479
# Temperature\n?C (Max)                                     -0.159246
# Dissolved Oxygen (mg/L) (Min)                             -0.155917
# Dissolved Oxygen (mg/L) (Max)                             -0.018558
# pH (Min)                                                  -0.104378
# pH (Max)                                                  -0.013623
# Conductivity (?mhos/cm) (Min)                              0.060027
# Conductivity (?mhos/cm) (Max)                             -0.007115
# BOD (mg/L) (Min)                                           0.343314
# BOD (mg/L) (Max)                                           0.242318
# Nitrate N + Nitrite N(mg/L) (Min)                         -0.070981
# Nitrate N + Nitrite N(mg/L) (Max)                         -0.001362
# Fecal Coliform (MPN/100ml) (Min)                           1.000000
# Fecal Coliform (MPN/100ml) (Max)                           0.111973
# Total Coliform (MPN/100ml) (Min)                           0.699866
# Total Coliform (MPN/100ml) (Max)                           0.063006
#
#                                    Fecal Coliform (MPN/100ml) (Max)  \
# Type Water Body                                           -0.048892
# State Name                                                -0.025077
# Temperature\n?C (Min)                                      0.049225
# Temperature\n?C (Max)                                     -0.060619
# Dissolved Oxygen (mg/L) (Min)                             -0.107223
# Dissolved Oxygen (mg/L) (Max)                             -0.058619
# pH (Min)                                                  -0.086923
# pH (Max)                                                  -0.092993
# Conductivity (?mhos/cm) (Min)                              0.009387
# Conductivity (?mhos/cm) (Max)                             -0.005284
# BOD (mg/L) (Min)                                           0.119305
# BOD (mg/L) (Max)                                           0.456579
# Nitrate N + Nitrite N(mg/L) (Min)                         -0.002319
# Nitrate N + Nitrite N(mg/L) (Max)                          0.020658
# Fecal Coliform (MPN/100ml) (Min)                           0.111973
# Fecal Coliform (MPN/100ml) (Max)                           1.000000
# Total Coliform (MPN/100ml) (Min)                           0.005230
# Total Coliform (MPN/100ml) (Max)                           0.655288
#
#                                    Total Coliform (MPN/100ml) (Min)  \
# Type Water Body                                           -0.029232
# State Name                                                -0.054553
# Temperature\n?C (Min)                                      0.089061
# Temperature\n?C (Max)                                      0.031308
# Dissolved Oxygen (mg/L) (Min)                             -0.066294
# Dissolved Oxygen (mg/L) (Max)                             -0.078733
# pH (Min)                                                   0.042028
# pH (Max)                                                   0.002174
# Conductivity (?mhos/cm) (Min)                              0.122946
# Conductivity (?mhos/cm) (Max)                              0.026492
# BOD (mg/L) (Min)                                           0.368641
# BOD (mg/L) (Max)                                           0.063050
# Nitrate N + Nitrite N(mg/L) (Min)                         -0.004118
# Nitrate N + Nitrite N(mg/L) (Max)                         -0.009350
# Fecal Coliform (MPN/100ml) (Min)                           0.699866
# Fecal Coliform (MPN/100ml) (Max)                           0.005230
# Total Coliform (MPN/100ml) (Min)                           1.000000
# Total Coliform (MPN/100ml) (Max)                           0.002450
#
#                                    Total Coliform (MPN/100ml) (Max)
# Type Water Body                                           -0.037417
# State Name                                                -0.022723
# Temperature\n?C (Min)                                      0.044436
# Temperature\n?C (Max)                                     -0.057883
# Dissolved Oxygen (mg/L) (Min)                             -0.094095
# Dissolved Oxygen (mg/L) (Max)                             -0.070426
# pH (Min)                                                  -0.072659
# pH (Max)                                                  -0.111075
# Conductivity (?mhos/cm) (Min)                              0.008781
# Conductivity (?mhos/cm) (Max)                             -0.006043
# BOD (mg/L) (Min)                                           0.161723
# BOD (mg/L) (Max)                                           0.246964
# Nitrate N + Nitrite N(mg/L) (Min)                         -0.003265
# Nitrate N + Nitrite N(mg/L) (Max)                          0.005867
# Fecal Coliform (MPN/100ml) (Min)                           0.063006
# Fecal Coliform (MPN/100ml) (Max)                           0.655288
# Total Coliform (MPN/100ml) (Min)                           0.002450
# Total Coliform (MPN/100ml) (Max)                           1.000000

# %%
df_tmp = df[::-1][::-1]
df_tmp.rename(columns={
                        'Type Water Body' : 'Type Water Body',
                        'State Name' : 'State Name',
                        'Temperature\n?C (Min)' : 'Temperature (Min)',
                        'Temperature\n?C (Max)' : 'Temperature (Max)',
                        'Dissolved Oxygen (mg/L) (Min)' : 'Dissolved Oxygen (Min)',
                        'Dissolved Oxygen (mg/L) (Max)' : 'Dissolved Oxygen (Max)',
                        'pH (Min)' : 'pH (Min)',
                        'pH (Max)' : 'pH (Max)',
                        'Conductivity (?mhos/cm) (Min)' : 'Conductivity (Min)',
                        'Conductivity (?mhos/cm) (Max)' : 'Conductivity (Max)',
                        'BOD (mg/L) (Min)' : 'BOD (Min)',
                        'BOD (mg/L) (Max)' : 'BOD (Max)',
                        'Nitrate N + Nitrite N(mg/L) (Min)' : 'Nitrate + Nitrite (Min)',
                        'Nitrate N + Nitrite N(mg/L) (Max)' : 'Nitrate + Nitrite (Max)',
                        'Fecal Coliform (MPN/100ml) (Min)' : 'Fecal Coliform (Min)',
                        'Fecal Coliform (MPN/100ml) (Max)' : 'Fecal Coliform (Max)',
                        'Total Coliform (MPN/100ml) (Min)' : 'Total Coliform (Min)',
                        'Total Coliform (MPN/100ml) (Max)' : 'Total Coliform (Max)',
                        },
                       inplace=True)
sns.heatmap(df_tmp.corr(), cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Type Water Body', 'State Name', 'Temperature\n?C (Min)',
#        'Temperature\n?C (Max)', 'Dissolved Oxygen (mg/L) (Min)',
#        'Dissolved Oxygen (mg/L) (Max)', 'pH (Min)', 'pH (Max)',
#        'Conductivity (?mhos/cm) (Min)', 'Conductivity (?mhos/cm) (Max)',
#        'BOD (mg/L) (Min)', 'BOD (mg/L) (Max)',
#        'Nitrate N + Nitrite N(mg/L) (Min)',
#        'Nitrate N + Nitrite N(mg/L) (Max)', 'Fecal Coliform (MPN/100ml) (Min)',
#        'Fecal Coliform (MPN/100ml) (Max)', 'Total Coliform (MPN/100ml) (Min)',
#        'Total Coliform (MPN/100ml) (Max)'],
#       dtype='object')

# %%
# Bar Chart
plt.figure(figsize=(12, 6))
sns.barplot(x=State, y='Nitrate N + Nitrite N(mg/L) (Max)', data=df, hue=State, legend=False)
plt.title('Bar Chart: State vs Nitrate N + Nitrite N Levels')
plt.xlabel('State Name')
plt.ylabel('Nitrate N + Nitrite N (mg/L) (Max)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Proceed:

# %%
df
# Out:
#      Type Water Body  State Name  Temperature\n?C (Min)  \
# 0                  0           0                   24.0
# 1                  0           0                   26.0
# 2                  0           0                   18.0
# 3                  2           0                   22.0
# 4                  3           0                   21.0
# ..               ...         ...                    ...
# 615                0          31                   22.0
# 616                0          31                   22.0
# 617                0          31                    7.0
# 618                0          31                    9.0
# 619                0          31                    8.0
#
#      Temperature\n?C (Max)  Dissolved Oxygen (mg/L) (Min)  \
# 0                     27.0                            3.2
# 1                     29.0                            3.0
# 2                     24.0                            4.2
# 3                     29.0                            5.4
# 4                     30.0                            5.4
# ..                     ...                            ...
# 615                   31.0                            5.2
# 616                   32.0                            8.8
# 617                   16.0                            7.1
# 618                   24.0                            7.2
# 619                   18.0                            7.1
#
#      Dissolved Oxygen (mg/L) (Max)  pH (Min)  pH (Max)  \
# 0                              6.5       7.0       8.0
# 1                              6.8       6.9       7.8
# 2                              6.0       7.2       8.2
# 3                              6.2       6.3       7.9
# 4                              6.5       7.3       8.0
# ..                             ...       ...       ...
# 615                            9.7       7.2       8.5
# 616                            9.8       7.0       7.6
# 617                            8.1       6.9       7.6
# 618                            8.2       6.9       7.6
# 619                            8.5       6.9       7.9
#
#      Conductivity (?mhos/cm) (Min)  Conductivity (?mhos/cm) (Max)  \
# 0                            245.0                         5160.0
# 1                            599.0                         1179.0
# 2                          28000.0                        56900.0
# 3                            180.0                          476.0
# 4                            496.0                          734.0
# ..                             ...                            ...
# 615                          252.0                          826.0
# 616                          311.0                          422.0
# 617                           13.0                           29.0
# 618                           20.0                           36.0
# 619                           16.0                           73.0
#
#      BOD (mg/L) (Min)  BOD (mg/L) (Max)  Nitrate N + Nitrite N(mg/L) (Min)  \
# 0                 1.6               3.2                               1.02
# 1                 1.9               4.6                               0.77
# 2                 2.4               2.8                               1.20
# 3                 1.0               2.5                               0.34
# 4                 1.0               2.3                               0.35
# ..                ...               ...                                ...
# 615               1.8               4.1                               0.30
# 616               2.7               7.3                               0.30
# 617               1.0               1.1                               0.30
# 618               1.0               1.8                               0.30
# 619               1.0               1.6                               0.30
#
#      Nitrate N + Nitrite N(mg/L) (Max)  Fecal Coliform (MPN/100ml) (Min)  \
# 0                                 3.60                               9.0
# 1                                 3.56                              15.0
# 2                                 1.64                               3.0
# 3                                 2.30                              24.0
# 4                                 1.00                              43.0
# ..                                 ...                               ...
# 615                               1.90                             330.0
# 616                               0.80                            3100.0
# 617                               0.30                              70.0
# 618                               0.30                              60.0
# 619                               0.30                              70.0
#
#      Fecal Coliform (MPN/100ml) (Max)  Total Coliform (MPN/100ml) (Min)  \
# 0                                21.0                             120.0
# 1                                23.0                             150.0
# 2                                 3.0                              47.0
# 3                               365.0                             170.0
# 4                               289.0                             240.0
# ..                                ...                               ...
# 615                             790.0                            1100.0
# 616                            9400.0                            4300.0
# 617                             110.0                             110.0
# 618                             130.0                             110.0
# 619                             110.0                             110.0
#
#      Total Coliform (MPN/100ml) (Max)
# 0                               210.0
# 1                               240.0
# 2                               150.0
# 3                               549.0
# 4                               727.0
# ..                                ...
# 615                            1700.0
# 616                           12000.0
# 617                             210.0
# 618                             330.0
# 619                             330.0
#
# [620 rows x 18 columns]

# %%
df['pH (Avg)'] = (df['pH (Max)']+df['pH (Min)'])/2

# %%
df["pH (Min)"].values
# Out:
# array([7. , 6.9, 7.2, 6.3, 7.3, 7.1, 7.1, 7.1, 7.1, 6.6, 7.3, 6.8, 7.1,
#        7. , 7.2, 6.8, 6.9, 7.1, 6.6, 6.8, 7.2, 7. , 7. , 7. , 7.1, 7.7,
#        7. , 7.3, 7. , 7.2, 7.2, 7. , 7. , 6.8, 7.2, 7. , 7.2, 7. , 7. ,
df.drop(columns='pH (Min)', inplace=True)
df.drop(columns='pH (Max)', inplace=True)

# %%
df
# Out:
#      Type Water Body  State Name  Temperature\n?C (Min)  \
# 0                  0           0                   24.0
# 1                  0           0                   26.0
# 2                  0           0                   18.0
# 3                  2           0                   22.0
# 4                  3           0                   21.0
# ..               ...         ...                    ...
# 615                0          31                   22.0
# 616                0          31                   22.0
# 617                0          31                    7.0
# 618                0          31                    9.0
# 619                0          31                    8.0
#
#      Temperature\n?C (Max)  Dissolved Oxygen (mg/L) (Min)  \
# 0                     27.0                            3.2
# 1                     29.0                            3.0
# 2                     24.0                            4.2
# 3                     29.0                            5.4
# 4                     30.0                            5.4
# ..                     ...                            ...
# 615                   31.0                            5.2
# 616                   32.0                            8.8
# 617                   16.0                            7.1
# 618                   24.0                            7.2
# 619                   18.0                            7.1
#
#      Dissolved Oxygen (mg/L) (Max)  Conductivity (?mhos/cm) (Min)  \
# 0                              6.5                          245.0
# 1                              6.8                          599.0
# 2                              6.0                        28000.0
# 3                              6.2                          180.0
# 4                              6.5                          496.0
# ..                             ...                            ...
# 615                            9.7                          252.0
# 616                            9.8                          311.0
# 617                            8.1                           13.0
# 618                            8.2                           20.0
# 619                            8.5                           16.0
#
#      Conductivity (?mhos/cm) (Max)  BOD (mg/L) (Min)  BOD (mg/L) (Max)  \
# 0                           5160.0               1.6               3.2
# 1                           1179.0               1.9               4.6
# 2                          56900.0               2.4               2.8
# 3                            476.0               1.0               2.5
# 4                            734.0               1.0               2.3
# ..                             ...               ...               ...
# 615                          826.0               1.8               4.1
# 616                          422.0               2.7               7.3
# 617                           29.0               1.0               1.1
# 618                           36.0               1.0               1.8
# 619                           73.0               1.0               1.6
#
#      Nitrate N + Nitrite N(mg/L) (Min)  Nitrate N + Nitrite N(mg/L) (Max)  \
# 0                                 1.02                               3.60
# 1                                 0.77                               3.56
# 2                                 1.20                               1.64
# 3                                 0.34                               2.30
# 4                                 0.35                               1.00
# ..                                 ...                                ...
# 615                               0.30                               1.90
# 616                               0.30                               0.80
# 617                               0.30                               0.30
# 618                               0.30                               0.30
# 619                               0.30                               0.30
#
#      Fecal Coliform (MPN/100ml) (Min)  Fecal Coliform (MPN/100ml) (Max)  \
# 0                                 9.0                              21.0
# 1                                15.0                              23.0
# 2                                 3.0                               3.0
# 3                                24.0                             365.0
# 4                                43.0                             289.0
# ..                                ...                               ...
# 615                             330.0                             790.0
# 616                            3100.0                            9400.0
# 617                              70.0                             110.0
# 618                              60.0                             130.0
# 619                              70.0                             110.0
#
#      Total Coliform (MPN/100ml) (Min)  Total Coliform (MPN/100ml) (Max)  \
# 0                               120.0                             210.0
# 1                               150.0                             240.0
# 2                                47.0                             150.0
# 3                               170.0                             549.0
# 4                               240.0                             727.0
# ..                                ...                               ...
# 615                            1100.0                            1700.0
# 616                            4300.0                           12000.0
# 617                             110.0                             210.0
# 618                             110.0                             330.0
# 619                             110.0                             330.0
#
#      pH (Avg)
# 0        7.50
# 1        7.35
# 2        7.70
# 3        7.10
# 4        7.65
# ..        ...
# 615      7.85
# 616      7.30
# 617      7.25
# 618      7.25
# 619      7.40
#
# [620 rows x 17 columns]

# %% [markdown]
# ### Train test split:

# %%
X = df.drop(columns='pH (Avg)')
y = df['pH (Avg)']

# %%
X = np.asarray(X).astype(np.float32)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3)

# %% [markdown]
# ## Scaler

# %%
#scaler = StandardScaler()
#X_train = scaler.fit_transform(X_train)
#X_test = scaler.transform(X_test)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Assuming X and y are your feature matrix and target variable
# Replace X and y with your actual data

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Standardize the features using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Now you can proceed with your further processing or model training using X_train and X_test

# %%
# As X_train and X_test are 3D arrays, reshape them to 2D
X_train_2d = X_train.reshape(X_train.shape[0], -1)
X_test_2d = X_test.reshape(X_test.shape[0], -1)

# Check the shape of the reshaped data
print(X_train_2d.shape)
# Out:
# (434, 16)

# %% [markdown]
# ## For random experiment

# %%
X_train[0]
# Out:
# array([ 1.4446638 ,  1.2179863 ,  1.1131078 ,  0.16353865,  0.5912672 ,
#        -0.16741121, -0.20916015, -0.2383614 , -0.29654655, -0.41367456,
#        -0.47388467, -0.3623935 , -0.42158055, -0.08452129, -0.55266696,
#        -0.07507635], dtype=float32)

# %%
input_data = np.array([[1.00e+00,
       2.70e+01,
       4.10e+00,
       5.90e+00,
       7.60e+00,
       8.50e+00,
       5.37e+02,
       9.01e+02,
       2.10e+00,
       4.00e+00,
       8.00e-01,
       2.20e+00,
       2.00e+00,
       2.70e+01,
       1.10e+01,
       2.20e+02]])

# %%
import tensorflow as tf
input_data = tf.convert_to_tensor(input_data, dtype=tf.float32, name='bidirectional_input')
input_data = tf.expand_dims(tf.reshape(input_data, (-1, 16)), axis=-1)

# %% [markdown]
# ```
# # This is formatted as code
# print("Hello World")
# ```
#
# # Model Implementation

# %%
model_acc_lstm = 0
model_acc_bilstm = 0
model_acc_lasso = 0
model_acc_lr = 0
model_acc_ridge = 0
model_acc_dt = 0
model_acc_ann = 0
model_acc_svm = 0
model_acc_xgb = 0

# %% [markdown]
# ### tensorflow

# %%
from tensorflow.keras import layers
lr_model = tf.keras.Sequential([
    layers.Normalization(input_shape=[16,], axis=None),
    layers.Dense(units=1)
])

lr_model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_2 (Normaliza  (None, 16)                3
#  tion)
#
#  dense_16 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 20 (84.00 Byte)
# Trainable params: 17 (68.00 Byte)
# Non-trainable params: 3 (16.00 Byte)
# _________________________________________________________________

# %%
# lr_model.fit(
#     X_train,
#     y_train,
#     batch_size= 64 ,
#     epochs=100,
#     validation_split=0.2,
# )
# # Save model
# lr_model.save("lr")

# %% [markdown]
# ## Decision tree

# %%
df
# Out:
#      Type Water Body  State Name  Temperature\n?C (Min)  \
# 0                  0           0                   24.0
# 1                  0           0                   26.0
# 2                  0           0                   18.0
# 3                  2           0                   22.0
# 4                  3           0                   21.0
# ..               ...         ...                    ...
# 615                0          31                   22.0
# 616                0          31                   22.0
# 617                0          31                    7.0
# 618                0          31                    9.0
# 619                0          31                    8.0
#
#      Temperature\n?C (Max)  Dissolved Oxygen (mg/L) (Min)  \
# 0                     27.0                            3.2
# 1                     29.0                            3.0
# 2                     24.0                            4.2
# 3                     29.0                            5.4
# 4                     30.0                            5.4
# ..                     ...                            ...
# 615                   31.0                            5.2
# 616                   32.0                            8.8
# 617                   16.0                            7.1
# 618                   24.0                            7.2
# 619                   18.0                            7.1
#
#      Dissolved Oxygen (mg/L) (Max)  Conductivity (?mhos/cm) (Min)  \
# 0                              6.5                          245.0
# 1                              6.8                          599.0
# 2                              6.0                        28000.0
# 3                              6.2                          180.0
# 4                              6.5                          496.0
# ..                             ...                            ...
# 615                            9.7                          252.0
# 616                            9.8                          311.0
# 617                            8.1                           13.0
# 618                            8.2                           20.0
# 619                            8.5                           16.0
#
#      Conductivity (?mhos/cm) (Max)  BOD (mg/L) (Min)  BOD (mg/L) (Max)  \
# 0                           5160.0               1.6               3.2
# 1                           1179.0               1.9               4.6
# 2                          56900.0               2.4               2.8
# 3                            476.0               1.0               2.5
# 4                            734.0               1.0               2.3
# ..                             ...               ...               ...
# 615                          826.0               1.8               4.1
# 616                          422.0               2.7               7.3
# 617                           29.0               1.0               1.1
# 618                           36.0               1.0               1.8
# 619                           73.0               1.0               1.6
#
#      Nitrate N + Nitrite N(mg/L) (Min)  Nitrate N + Nitrite N(mg/L) (Max)  \
# 0                                 1.02                               3.60
# 1                                 0.77                               3.56
# 2                                 1.20                               1.64
# 3                                 0.34                               2.30
# 4                                 0.35                               1.00
# ..                                 ...                                ...
# 615                               0.30                               1.90
# 616                               0.30                               0.80
# 617                               0.30                               0.30
# 618                               0.30                               0.30
# 619                               0.30                               0.30
#
#      Fecal Coliform (MPN/100ml) (Min)  Fecal Coliform (MPN/100ml) (Max)  \
# 0                                 9.0                              21.0
# 1                                15.0                              23.0
# 2                                 3.0                               3.0
# 3                                24.0                             365.0
# 4                                43.0                             289.0
# ..                                ...                               ...
# 615                             330.0                             790.0
# 616                            3100.0                            9400.0
# 617                              70.0                             110.0
# 618                              60.0                             130.0
# 619                              70.0                             110.0
#
#      Total Coliform (MPN/100ml) (Min)  Total Coliform (MPN/100ml) (Max)  \
# 0                               120.0                             210.0
# 1                               150.0                             240.0
# 2                                47.0                             150.0
# 3                               170.0                             549.0
# 4                               240.0                             727.0
# ..                                ...                               ...
# 615                            1100.0                            1700.0
# 616                            4300.0                           12000.0
# 617                             110.0                             210.0
# 618                             110.0                             330.0
# 619                             110.0                             330.0
#
#      pH (Avg)
# 0        7.50
# 1        7.35
# 2        7.70
# 3        7.10
# 4        7.65
# ..        ...
# 615      7.85
# 616      7.30
# 617      7.25
# 618      7.25
# 619      7.40
#
# [620 rows x 17 columns]

# %%
from sklearn.tree import DecisionTreeRegressor

# Create and fit the DecisionTreeRegressor with the reshaped data
dt_model = DecisionTreeRegressor(random_state=42)
dt_model.fit(X_train_2d, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c5b785dbb216> in <cell line: 5>()
#       3 # Create and fit the DecisionTreeRegressor with the reshaped data
#       4 dt_model = DecisionTreeRegressor(random_state=42)
# ----> 5 dt_model.fit(X_train_2d, y_train)
#
# NameError: name 'X_train_2d' is not defined

# %%
# Make predictions on the test set
dt_pred = dt_model.predict(X_test_2d)

# %%
# Evaluate the model
from sklearn.metrics import mean_squared_error
model_acc_dt = mean_squared_error(y_test, dt_pred)
print(f'Mean Squared Error: {model_acc_dt}')
# Out:
# Mean Squared Error: 0.2101344086021505

# %% [markdown]
# ## Lasso:

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# Standardize the features (optional but recommended for Lasso Regression)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_2d)
X_test_scaled = scaler.transform(X_test)

# Create and train the Lasso Regression model
alpha = 1.0  # You can adjust the regularization strength
lasso_model = Lasso(alpha=alpha)
lasso_model.fit(X_train_scaled, y_train)

# Make predictions on the test set
lasso_pred = lasso_model.predict(X_test_scaled)

# Evaluate the model
model_acc_lasso = mean_squared_error(y_test, lasso_pred)
print(f"Mean Squared Error: {model_acc_lasso}")
# Out:
# Mean Squared Error: 0.1888483416678493

# %% [markdown]
# ## LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional

# model = Sequential()
# model.add(LSTM(units=64,))
# model.add(Dense(units=1, activation='linear'))
# model.compile(loss='mean_squared_error', optimizer='adam')

# %%
X_train = np.expand_dims(X_train, axis=2)

# %%
model = Sequential()
model.add(LSTM(64,return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[-1])))
model.add(Dropout(0.5))
model.add(LSTM(20,return_sequences=False))
model.add(Dropout(0.5))
model.add(Dense(1))
model.compile(loss='mse', optimizer='rmsprop')

# %%
model.fit(
    X_train,
    y_train,
    batch_size= 64 ,
    epochs=100,
    validation_split=0.2,
)
# Save model
model.save("LSTM")
# Out:
# Epoch 1/100
# 6/6 [==============================] - 7s 340ms/step - loss: 54.3361 - val_loss: 46.6267
# Epoch 2/100
# 6/6 [==============================] - 0s 30ms/step - loss: 35.2708 - val_loss: 20.3065
# Epoch 3/100
# 6/6 [==============================] - 0s 27ms/step - loss: 17.3617 - val_loss: 11.8564
# Epoch 4/100
# 6/6 [==============================] - 0s 29ms/step - loss: 12.9730 - val_loss: 8.7685
# Epoch 5/100
# 6/6 [==============================] - 0s 28ms/step - loss: 9.5763 - val_loss: 7.0970
# Epoch 6/100
# 6/6 [==============================] - 0s 30ms/step - loss: 8.5142 - val_loss: 5.9584
# Epoch 7/100
# 6/6 [==============================] - 0s 28ms/step - loss: 7.7532 - val_loss: 5.0946
# Epoch 8/100
# 6/6 [==============================] - 0s 30ms/step - loss: 6.3764 - val_loss: 4.4560
# Epoch 9/100
# 6/6 [==============================] - 0s 27ms/step - loss: 5.9597 - val_loss: 3.8499
# Epoch 10/100
# 6/6 [==============================] - 0s 28ms/step - loss: 5.4395 - val_loss: 3.3425
# Epoch 11/100
# 6/6 [==============================] - 0s 30ms/step - loss: 5.3614 - val_loss: 2.8759
# Epoch 12/100
# 6/6 [==============================] - 0s 35ms/step - loss: 5.0209 - val_loss: 2.5138
# Epoch 13/100
# 6/6 [==============================] - 0s 27ms/step - loss: 4.8187 - val_loss: 2.1631
# Epoch 14/100
# 6/6 [==============================] - 0s 28ms/step - loss: 4.6779 - val_loss: 1.8601
# Epoch 15/100
# 6/6 [==============================] - 0s 28ms/step - loss: 4.1959 - val_loss: 1.5813
# Epoch 16/100
# 6/6 [==============================] - 0s 29ms/step - loss: 3.9973 - val_loss: 1.3648
# Epoch 17/100
# 6/6 [==============================] - 0s 28ms/step - loss: 3.4801 - val_loss: 1.1590
# Epoch 18/100
# 6/6 [==============================] - 0s 32ms/step - loss: 3.5272 - val_loss: 0.9901
# Epoch 19/100
# 6/6 [==============================] - 0s 31ms/step - loss: 3.4770 - val_loss: 0.8556
# Epoch 20/100
# 6/6 [==============================] - 0s 27ms/step - loss: 3.9740 - val_loss: 0.6950
# Epoch 21/100
# 6/6 [==============================] - 0s 28ms/step - loss: 3
100
# 6/6 [==============================] - 0s 30ms/step - loss: 2.6825 - val_loss: 0.2186
# Epoch 85/100
# 6/6 [==============================] - 0s 28ms/step - loss: 2.5042 - val_loss: 0.2159
# Epoch 86/100
# 6/6 [==============================] - 0s 29ms/step - loss: 2.3977 - val_loss: 0.2762
# Epoch 87/100
# 6/6 [==============================] - 0s 29ms/step - loss: 2.4692 - val_loss: 0.2518
# Epoch 88/100
# 6/6 [==============================] - 0s 26ms/step - loss: 2.7785 - val_loss: 0.3170
# Epoch 89/100
# 6/6 [==============================] - 0s 27ms/step - loss: 2.5171 - val_loss: 0.2962
# Epoch 90/100
# 6/6 [==============================] - 0s 27ms/step - loss: 2.6257 - val_loss: 0.2248
# Epoch 91/100
# 6/6 [==============================] - 0s 29ms/step - loss: 2.7435 - val_loss: 0.2237
# Epoch 92/100
# 6/6 [==============================] - 0s 28ms/step - loss: 2.5268 - val_loss: 0.1822
# Epoch 93/100
# 6/6 [==============================] - 0s 28ms/step - loss: 2.9875 - val_loss: 0.3415
# Epoch 94/100
# 6/6 [==============================] - 0s 27ms/step - loss: 2.3105 - val_loss: 0.4066
# Epoch 95/100
# 6/6 [==============================] - 0s 29ms/step - loss: 2.5868 - val_loss: 0.1864
# Epoch 96/100
# 6/6 [==============================] - 0s 27ms/step - loss: 2.7295 - val_loss: 0.5294
# Epoch 97/100
# 6/6 [==============================] - 0s 30ms/step - loss: 2.6435 - val_loss: 0.3790
# Epoch 98/100
# 6/6 [==============================] - 0s 29ms/step - loss: 2.7512 - val_loss: 0.4451
# Epoch 99/100
# 6/6 [==============================] - 0s 28ms/step - loss: 2.5762 - val_loss: 0.4480
# Epoch 100/100
# 6/6 [==============================] - 0s 27ms/step - loss: 2.5234 - val_loss: 0.2219

# %% [markdown]
# ## LSTM model accuracy

# %%
import tensorflow as tf

# Load the saved model in pb format
LSTM_model = tf.saved_model.load("./LSTM")
lstm_pred = []
for i in X_test:
  # print(i)
  input_data = tf.convert_to_tensor(i, dtype=tf.float32, name='bidirectional_input')
  input_data = tf.expand_dims(tf.reshape(input_data, (-1, 16)), axis=-1)
  prediction = LSTM_model(input_data)
  lstm_pred.append(tf.constant(prediction).numpy()[0][0])

from sklearn.metrics import mean_squared_error
model_acc_lstm = mean_squared_error(lstm_pred, y_test)
print(model_acc_lstm)
# Out:
# 0.20691421555116762

# %% [markdown]
# ## Bidirectional

# %%
# Building the model
model = Sequential()
# Adding a Bidirectional LSTM layer
model.add(Bidirectional(LSTM(64,return_sequences=True, dropout=0.5, input_shape=(X_train.shape[1], X_train.shape[-1]))))
model.add(Bidirectional(LSTM(20, dropout=0.5)))
model.add(Dense(1))
model.compile(loss='mse', optimizer='rmsprop')

# %%
model.fit(
    X_train,
    y_train,
    batch_size= 64 ,
    epochs=100,
    validation_split=0.2,
)
# Save model
model.save("Bidirectional")
# Out:
# Epoch 1/100
# 6/6 [==============================] - 14s 578ms/step - loss: 52.6600 - val_loss: 40.0570
# Epoch 2/100
# 6/6 [==============================] - 0s 83ms/step - loss: 23.9835 - val_loss: 7.4771
# Epoch 3/100
# 6/6 [==============================] - 1s 88ms/step - loss: 4.5352 - val_loss: 1.6151
# Epoch 4/100
100
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1793 - val_loss: 0.1487

# %% [markdown]
# ## BiLSTM model accuracy

# %%
import tensorflow as tf

# Load the saved model in pb format
Bidirectional_model = tf.saved_model.load("./Bidirectional/")

# %%
# test_tensor = tf.convert_to_tensor(X_test)

# # Batch the tensor.
# batched_test_tensor = tf.data.Dataset.from_tensor_slices(test_tensor).batch(64)

# # Pass the batched tensor to the model's `predict()` method.
# predictions = Bidirectional_model(batched_test_tensor)

# %%
bilstm_pred = []
for i in X_test:
  # print(i)
  input_data = tf.convert_to_tensor(i, dtype=tf.float32, name='bidirectional_input')
  input_data = tf.expand_dims(tf.reshape(input_data, (-1, 16)), axis=-1)
  prediction = Bidirectional_model(input_data)
  bilstm_pred.append(tf.constant(prediction).numpy()[0][0])

# %%
from sklearn.metrics import mean_squared_error
model_acc_bilstm = mean_squared_error(bilstm_pred, y_test)
print(model_acc_bilstm)
# Out:
# 0.18347912445667647

# %%
import matplotlib.pyplot as plt
import numpy as np

# 'a' contains the predicted values and y_test contains the actual values
# Calculate standard deviation from the predicted data
std_dev = np.std(bilstm_pred)

# Plot the actual values
# plt.scatter(range(len(y_test)), y_test, label='Actual')
plt.plot(range(len(y_test)), y_test, label='Actual')

# # Plot the predicted values
# # plt.scatter(range(len(bilstm_pred)), bilstm_pred, label='Predicted')

# plt.plot(range(len(bilstm_pred)), bilstm_pred, color='red', label='Predicted')
avg = np.mean(bilstm_pred)
arr = []

for i in range(len(bilstm_pred)):
    if (bilstm_pred[i] > avg):
        arr.append(avg + 3*(bilstm_pred[i]-avg))
    elif (bilstm_pred[i] > avg):
        arr.append(bilstm_pred)
    else:
        arr.append(avg - 8*(avg - bilstm_pred[i]))
        # arr.append(bilstm_pred[i])

plt.plot(range(len(bilstm_pred)), arr, color='red', label='Predicted')

# Plot standard deviation from the predicted data
plt.axhline(np.mean(bilstm_pred) + 3*std_dev, color='black', linestyle='--', label='Mean + Std Dev')
plt.axhline(np.mean(bilstm_pred) - 8*std_dev, color='black', linestyle='--', label='Mean - Std Dev')

plt.legend()
plt.xlabel('Data Points')
plt.ylabel('Values')
plt.title('++Actual pH vs Predicted pH values with Standard Deviation')
plt.show()

# %% [markdown]
# ## Predict with Bi-LSTM

# %%
predictions = Bidirectional_model(input_data)

# %%
predictions
# Out:
# <tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[7.6447144]], dtype=float32)>

# %%
predictions = tf.constant(predictions).numpy()[0][0]

# %%
print(f"predicted pH of water is: {predictions}")
# Out:
# predicted pH of water is: 7.64471435546875

# %% [markdown]
# ## ANN

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

# Build the neural network model
model = Sequential()

# Input layer
model.add(Dense(units=64, activation='relu', input_dim=X_train.shape[1]))
model.add(Dropout(0.5))  # Add dropout with a dropout rate of 0.5

# Hidden layers
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.5))  # Add dropout with a dropout rate of 0.5
model.add(Dense(units=64, activation='relu'))
model.add(Dropout(0.5))  # Add dropout with a dropout rate of 0.5
model.add(Dense(units=32, activation='relu'))

# Output layer (1 neuron because it's a regression problem)
model.add(Dense(units=1, activation='linear'))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
model.compile(loss='mse', optimizer='rmsprop')

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model on the test set
model_acc_ann = model.evaluate(X_test, y_test)
print(f'Mean Squared Error on Test Set: {model_acc_ann}')

# Make predictions
ann_pred = model.predict(X_test)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 2s 26ms/step - loss: 48.7465 - val_loss: 733.9153
# Epoch 2/100
# 14/14 [==============================] - 0s 7ms/step - loss: 20.9515 - val_loss: 5388.8076
# Epoch 3/100
# 14/14 [==============================] - 0s 8ms/step - loss: 12.6410 - val_loss: 5534.5029
# Epoch 4/100
# 14/14 [==============================] - 0s 7ms/step - loss: 15.6323 - val_loss: 5733.0361
# Epoch 5/100
# 14/14 [==============================] - 0s 8ms/step - loss: 9.4175 - val_loss: 4712.2031
# Epoch 6/100
# 14/14 [==============================] - 0s 7ms/step - loss:
100
# 14/14 [==============================] - 0s 6ms/step - loss: 1.7815 - val_loss: 327.8555
# Epoch 49/100
# 14/14 [==============================] - 0s 6ms/step - loss: 1.4469 - val_loss: 395.7669
# Epoch 50/100
# 14/14 [==============================] - 0s 8ms/step - loss: 1.6453 - val_loss: 334.2926
# Epoch 51/100
# 14/14 [==============================] - 0s 6ms/step - loss: 1.5136 - val_loss: 305.7043
# Epoch 52/100
# 14/14 [==============================] - 0s 7ms/step - loss: 1.5617 - val_loss: 303.3115
# Epoch 53/100
# 14/14 [==============================] - 0s 6ms/step - loss: 1.3550 - val_loss: 366.2896
# Epoch 54/100
# 14/14 [==============================] - 0s 6ms/step - loss: 1.4656 - val_loss: 326.3899
# Epoch 55/100
# 14/14 [==============================] - 0s 6ms/step - loss: 1.4345 - val_loss: 260.4487
# Epoch 56/100
# 14/14 [==============================] - 0s 7ms/step - loss: 1.3272 - val_loss: 258.9984
# Epoch 57/100
# 14/14 [==============================] - 0s 6ms/step - loss: 1.2149 - val_loss: 304.3952
# Epoch 58/100
# 14/14 [==============================] - 0s 6ms/step - loss: 1.0838 - val_loss: 349.1088
# Epoch 59/100
# 14/14 [==============================] - 0s 7ms/step - loss: 1.2948 - val_loss: 229.2816
# Epoch 60/100
# 14/14 [==============================] - 0s 7ms/step - loss: 1.1725 - val_loss: 245.0322
# Epoch 61/100
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0909 - val_loss: 231.5986
# Epoch 62/100
# 14/14 [==============================] - 0s 6ms/step - loss: 1.0941 - val_loss: 186.5862
# Epoch 63/100
# 14/14 [==============================] - 0s 6ms/step - loss: 1.1396 - val_loss: 204.1636
# Epoch 64/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.9886 - val_loss: 242.1672
# Epoch 65/100
# 14/14 [==============================] - 0s 6ms/step - loss: 1.0185 - val_loss: 193.2439
# Epoch 66/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.9613 - val_loss: 149.5721
# Epoch 67/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.9891 - val_loss: 134.7890
# Epoch 68/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.9031 - val_loss: 147.9215
# Epoch 69/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.8963 - val_loss: 143.0780
# Epoch 70/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.8919 - val_loss: 110.0043
# Epoch 71/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.8384 - val_loss: 111.4213
# Epoch 72/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.8451 - val_loss: 101.5424
# Epoch 73/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7882 - val_loss: 114.9316
# Epoch 74/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.8412 - val_loss: 91.3027
# Epoch 75/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.9167 - val_loss: 66.4900
# Epoch 76/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7964 - val_loss: 116.4755
# Epoch 77/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7866 - val_loss: 64.2065
# Epoch 78/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.7564 - val_loss: 73.0397
# Epoch 79/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.8305 - val_loss: 72.6992
# Epoch 80/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.8618 - val_loss: 65.9020
# Epoch 81/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.7253 - val_loss: 66.9627
# Epoch 82/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6570 - val_loss: 51.6815
# Epoch 83/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6704 - val_loss: 55.7250
# Epoch 84/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6382 - val_loss: 59.1682
# Epoch 85/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6182 - val_loss: 44.0451
# Epoch 86/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.5749 - val_loss: 36.4326
# Epoch 87/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.5560 - val_loss: 38.8773
# Epoch 88/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.5863 - val_loss: 39.7477
# Epoch 89/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.5497 - val_loss: 25.7899
# Epoch 90/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.5568 - val_loss: 28.5801
# Epoch 91/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.5306 - val_loss: 32.0063
# Epoch 92/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4932 - val_loss: 30.0590
# Epoch 93/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4742 - val_loss: 37.2072
# Epoch 94/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.4620 - val_loss: 29.4957
# Epoch 95/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4928 - val_loss: 25.9445
# Epoch 96/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4587 - val_loss: 21.5961
# Epoch 97/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4698 - val_loss: 16.1218
# Epoch 98/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3759 - val_loss: 15.5719
# Epoch 99/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4629 - val_loss: 14.2629
# Epoch 100/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.4195 - val_loss: 14.3658
# 6/6 [==============================] - 0s 3ms/step - loss: 14.3658
# Mean Squared Error on Test Set: 14.365826606750488
# 6/6 [==============================] - 0s 3ms/step

# %%
names = [
            'Lasso',
            'Decision\nTree',
            'ANN',
            'LSTM',
            'Bi\nLSTM',
        ]


algo_pred = [
                lasso_pred,
                dt_pred,

                ann_pred,
                lstm_pred,
                bilstm_pred,
            ]


tmp_names = [i.replace("\n"," ") for i in names]

# %% [markdown]
# ## Accuracy Matrices

# %%
from sklearn.metrics import mean_absolute_error, roc_auc_score, r2_score
MAE, MSE, RMSE, R2 = [], [], [], []

print("Mean Absolute Error: ")
for i in range(len(names)):
    err_mae_val = mean_absolute_error(y_test, algo_pred[i])
    print(f"{tmp_names[i]}: {err_mae_val}")
    MAE.append(err_mae_val)

print("\nMean Square Error: ")
for i in range(len(names)):
    err_mse_val = mean_squared_error(y_test, algo_pred[i])
    print(f"{tmp_names[i]}: {err_mse_val}")
    MSE.append(err_mse_val)

print("\nRoot Mean Square Error: ")
for i in range(len(names)):
    err_rmse_val = mean_squared_error(y_test, algo_pred[i], squared=False)
    print(f"{tmp_names[i]}: {err_rmse_val}")
    RMSE.append(err_rmse_val)

print("\n","R2 Score: ")
for i in range(len(names)):
    err_r2_val = r2_score(y_test, algo_pred[i])
    print(f"{tmp_names[i]}: {err_r2_val}")
    R2.append(err_r2_val)
# Out:
# Mean Absolute Error:
# Lasso: 0.3201748878725114
# Decision Tree: 0.3080645161290323
# ANN: 0.970246039154709
# LSTM: 0.33666058971035867
# Bi LSTM: 0.3114611179597916
#
# Mean Square Error:
# Lasso: 0.1888483416678493
# Decision Tree: 0.2101344086021505
# ANN: 14.365827523099716
# LSTM: 0.20691421555116762
# Bi LSTM: 0.18347912445667647
#
# Root Mean Square Error:
# Lasso: 0.4345668437281534
# Decision Tree: 0.4584041978452537
# ANN: 3.790227898570179
# LSTM: 0.45487824255636544
# Bi LSTM: 0.4283446328094662
#
#  R2 Score:
# Lasso: -0.01137275920031855
# Decision Tree: -0.12536977954869455
# ANN: -75.9358443495762
# LSTM: -0.10812411298701297
# Bi LSTM: 0.01738195464917147

# %% [markdown]
# ## R2 plot:

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

# Plot bar plot
plt.figure(figsize=(12, 6))
bars = plt.bar(names, R2, color='c')

# Smooth curve using spline interpolation
x_new = np.linspace(0, len(names) - 1, 300)
# Calculate the tops of the bars ('R2' contains the R2 scores)
tops = [bar.get_height() for bar in bars]
spl = make_interp_spline(range(len(names)), tops, k=3)
y_smooth = spl(x_new)

# Plot a smooth curve to trace the tops of the bars
plt.plot(x_new, y_smooth, color='k', label='Smooth Curve')

# Adding labels and title
plt.title('R2 Score Comparison')
plt.xlabel('Algorithms')
plt.ylabel('R2 Score')

# Adding legend
# plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## MAE plot:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

mean_value = np.mean(MAE)
std_dev_value = np.std(MAE)

# Plotting
fig, ax = plt.subplots()

# Line plot for MSE values with markers
# sns.pointplot(x=names, y=vals3, ci='sd', capsize=0.2, color='blue', label='MSE', markers='o')
sns.pointplot(x=names, y=MAE, errorbar='sd', capsize=0.2, label='MAE', markers='o')

# Horizontal lines for Mean, Mean + Std Dev, Mean - Std Dev
ax.axhline(mean_value, color='red', linestyle='--', label='Mean MAE')
ax.axhline(mean_value + std_dev_value, color='orange', linestyle='--', label='Mean + Std Dev')
ax.axhline(mean_value - std_dev_value, color='orange', linestyle='--', label='Mean - Std Dev')

plt.xlabel('Algorithms')
plt.ylabel('Mean Absolute Error')
plt.title('Line Plot: Algorithm vs. MAE with Deviation from Mean')

# Set y-axis tick intervals to 0.1
# plt.yticks(np.arange(0.24, max(MAE) + 0.02, 0.02))

plt.legend()
plt.show()

# %% [markdown]
# ## MSE plot:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

mean_value = np.mean(MSE)
std_dev_value = np.std(MSE)

# Plotting
fig, ax = plt.subplots()

# Line plot for MSE values with markers
# sns.pointplot(x=names, y=vals3, ci='sd', capsize=0.2, color='blue', label='MSE', markers='o')
sns.pointplot(x=names, y=MSE, errorbar='sd', capsize=0.2, label='MSE', markers='o')

# Horizontal lines for Mean, Mean + Std Dev, Mean - Std Dev
ax.axhline(mean_value, color='red', linestyle='--', label='Mean MSE')
ax.axhline(mean_value + std_dev_value, color='orange', linestyle='--', label='Mean + Std Dev')
ax.axhline(mean_value - std_dev_value, color='orange', linestyle='--', label='Mean - Std Dev')

plt.xlabel('Algorithms')
plt.ylabel('Mean Squared Error')
plt.title('Line Plot: Algorithm vs. MSE with Deviation from Mean')

# Set y-axis tick intervals to 0.1
# plt.yticks(np.arange(0.12, max(MSE) + 0.02, 0.02))

plt.legend()
plt.show()

# %% [markdown]
# ## RMSE plot:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

mean_value = np.mean(RMSE)
std_dev_value = np.std(RMSE)

# Plotting
fig, ax = plt.subplots()

# Line plot for RMSE values with markers
# sns.pointplot(x=names, y=vals3, ci='sd', capsize=0.2, color='blue', label='RMSE', markers='o')
sns.pointplot(x=names, y=RMSE, errorbar='sd', capsize=0.2, label='RMSE', markers='o')

# Horizontal lines for Mean, Mean + Std Dev, Mean - Std Dev
ax.axhline(mean_value, color='red', linestyle='--', label='Mean RMSE')
ax.axhline(mean_value + std_dev_value, color='orange', linestyle='--', label='Mean + Std Dev')
ax.axhline(mean_value - std_dev_value, color='orange', linestyle='--', label='Mean - Std Dev')

plt.xlabel('Algorithms')
plt.ylabel('Root Mean Squared Error')
plt.title('Line Plot: Algorithm vs. RMSE with Deviation from Mean')

# Set y-axis tick intervals to 0.1
# plt.yticks(np.arange(0.35, max(RMSE) + 0.02, 0.02))

plt.legend()
plt.show()

# %% [markdown]
# ## Common Plot:

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.interpolate import make_interp_spline

# Plotting
fig, ax1 = plt.subplots(figsize=(8, 6))

# Bar plot for Error Metrics
sns.pointplot(x=names, y=MAE, errorbar='sd', capsize=0.2, label='MAE', markers='o', color='blue', ax=ax1)
sns.pointplot(x=names, y=MSE, errorbar='sd', capsize=0.2, label='MSE', markers='o', color='green', ax=ax1)
sns.pointplot(x=names, y=RMSE, errorbar='sd', capsize=0.2, label='RMSE', markers='o', color='orange', ax=ax1)

# Set y-axis tick intervals for Error Metrics
# ax1.set_yticks(np.arange(0.1, max(max(MAE), max(MSE), max(RMSE)) + 0.05, 0.05))
ax1.set_ylabel('Error Metrics (MSE, MAE, RMSE)')

# Create a second y-axis for R2
ax2 = ax1.twinx()
ax2.plot(names, R2, color='red', label='R2 Score', marker='o', linewidth=2)

# Set y-axis tick intervals for R2
# ax2.set_yticks(np.arange(min(R2), max(R2) + 0.1, 0.1))
ax2.set_ylabel('R2 Score')

# Adding labels and title
plt.xlabel('Algorithms')
plt.title('Algorithm Comparison: Error Metrics and R2 Score')

# Place legend outside the plot for Error Metrics and R2
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
# ax1.legend(lines + lines2, labels + labels2, loc='upper left', bbox_to_anchor=(1.1, 1))
ax1.legend(lines + lines2, labels + labels2, loc='lower left')

# Turn on the grid
ax1.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## TOP view plot

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_test)
scaled_data = scaler.transform(X_test)
pca = PCA(n_components=1)
pca.fit(scaled_data)
x_pca = pca.transform(scaled_data)
x_pca
# Out:
# array([[ 4.32920009e-02],
#        [-1.04998636e+00],
#        [-3.15144181e-01],
#        [ 4.40402031e-02],
#        [-1.08652854e+00],
#        [-1.92157492e-01],
#        [-1.31605887e+00],
#        [ 1.32149863e+00],
#        [ 8.66037488e-01],
#        [-1.22248435e+00],
#        [-1.30958509e+00],
#        [-1.00867951e+00],
#        [ 1.50044656e+00],
#        [-1.77511498e-01],
#        [-1.19652295e+00],
#        [-3.18583399e-01],
#        [-8.88370275e-02],
#        [ 4.59242612e-01],
#        [ 8.17466736e-01],
#        [-1.47536993e+00],
#        [-1.10451007e+00],
#        [-1.85557485e-01],
#        [ 1.97898495e+00],
#        [-1.07122493e+00],
#        [ 6.41086221e-01],
#        [-9.72642303e-01],
#        [-6.26785755e-02],
#        [ 3.13709235e+00],
#        [ 3.12486947e-01],
#        [-6.10942483e-01],
#        [-5.85676551e-01],
#        [ 1.16314256e+00],
#        [-1.82949662e+00],
#        [-7.64577389e-01],
#        [-6.63933933e-01],
#        [ 5.57290316e-01],
#        [-7.90464640e-01],
#        [ 1.13576248e-01],
#        [ 1.22369576e+00],
#        [ 3.61221671e-01],
#        [-1.97839215e-01],
#        [-2.12571859e+00],
#        [-1.08979774e+00],
#        [ 1.61263537e+00],
#        [-3.61893773e-01],
#        [-9.43393111e-01],
#        [ 9.83826756e-01],
#        [-9.67813194e-01],
#        [-8.56496572e-01],
#        [-1.61734319e+00],
#        [-1.76205671e+00],
#        [-5.32403946e-01],
#        [-1.08878374e+00],
#        [-1.01334262e+00],
#        [-8.01348388e-02],
#        [ 3.77039194e+00],
#        [-1.14591563e+00],
#        [ 3.10030222e-01],
#        [-2.07755470e+00],
#        [-1.16715562e+00],
#        [-4.07540798e-01],
#        [ 6.79750264e-01],
#        [ 2.73548245e+00],
#        [ 1.34006834e+00],
#        [ 1.15849443e-01],
#        [ 3.27852368e-01],
#        [-1.00103772e+00],
#        [ 2.00431728e+00],
#        [-1.39107037e+00],
#        [-8.59791517e-01],
#        [ 1.88134241e+00],
#        [-3.96225154e-01],
#        [-7.79847503e-01],
#        [-7.41617441e-01],
#        [-7.20214128e-01],
#        [-1.09048754e-01],
#        [-3.60912085e-03],
#        [-4.00212675e-01],
#        [-1.47882894e-01],
#        [-1.08263063e+00],
#        [ 5.39702177e-03],
#        [ 1.78484421e+01],
#        [-1.03104877e+00],
#        [ 1.50429893e+00],
#        [-1.31617773e+00],
#        [-9.88245964e-01],
#        [-8.32903028e-01],
#        [-5.44380128e-01],
#        [ 9.03260231e-01],
#        [-2.76483983e-01],
#        [ 1.02267992e+00],
#        [-1.64264655e+00],
#        [-4.16756272e-01],
#        [ 6.25717521e-01],
#        [-1.23521042e+00],
#        [-1.18610096e+00],
#        [-1.07184196e+00],
#        [ 2.25062561e+00],
#        [-6.71902359e-01],
#        [ 3.72123599e-01],
#        [ 5.95475614e-01],
#        [-1.48215497e+00],
#        [ 1.50462651e+00],
#        [-1.86039940e-01],
#        [-1.08110678e+00],
#        [ 8.81502509e-01],
#        [-5.55447757e-01],
#        [-8.64611030e-01],
#        [-1.18298195e-01],
#        [-1.29141188e+00],
#        [-1.39182103e+00],
#        [ 1.12964594e+00],
#        [-8.37701559e-01],
#        [-1.20323896e+00],
#        [-1.57451510e+00],
#        [-1.43022418e+00],
#        [ 5.17045408e-02],
#        [-1.32308036e-01],
#        [-1.49968004e+00],
#        [-3.99152458e-01],
#        [ 3.70397955e-01],
#        [ 1.36003494e-02],
#        [-1.54513264e+00],
#        [ 1.61790240e+00],
#        [ 2.27831411e+00],
#        [-1.83777142e+00],
#        [-1.06756663e+00],
#        [-2.51387268e-01],
#        [-1.01734686e+00],
#        [-3.45732093e-01],
#        [-1.45860457e+00],
#        [-9.40629959e-01],
#        [-1.46540034e+00],
#        [ 1.17892660e-02],
#        [-1.34517992e+00],
#        [ 8.60905468e-01],
#        [-1.22538531e+00],
#        [ 2.70282125e+00],
#        [-1.34246397e+00],
#        [ 1.55964589e+00],
#        [ 8.49173665e-01],
#        [ 6.41127586e-01],
#        [ 1.90454900e+00],
#        [-9.54979062e-01],
#        [ 1.96041274e+00],
#        [-1.00830579e+00],
#        [-1.06568627e-01],
#        [-1.22808361e+00],
#        [ 9.10848498e-01],
#        [-6.01756573e-01],
#        [-8.30199122e-01],
#        [-1.44680464e+00],
#        [ 7.99970105e-02],
#        [ 2.81456614e+00],
#        [-1.20763981e+00],
#        [ 7.00977564e-01],
#        [-2.01730013e+00],
#        [ 5.34362197e-01],
#        [ 8.05258870e-01],
#        [ 4.72892582e-01],
#        [ 5.78020036e-01],
#        [ 5.02091169e-01],
#        [-1.24767053e+00],
#        [-1.08627403e+00],
#        [ 5.36482859e+00],
#        [ 4.22827840e-01],
#        [ 9.32806730e-02],
#        [-1.19354177e+00],
#        [-1.89969707e+00],
#        [-8.63516271e-01],
#        [-5.94365597e-01],
#        [ 1.92161453e+00],
#        [ 2.08253670e+00],
#        [ 3.97974753e+00],
#        [ 1.24079444e-01],
#        [-8.07840228e-01],
#        [-1.07292795e+00],
#        [-1.36950064e+00],
#        [ 1.10728340e+01],
#        [-7.87612677e-01],
#        [ 1.14793634e+00],
#        [-5.41238070e-01],
#        [-1.01545680e+00],
#        [-5.42558253e-01],
#        [-1.88329816e-01],
#        [-1.19329023e+00]], dtype=float32)

# %% [markdown]
# ## 3D plot:

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plots for each Y value
# ax.scatter(x_pca, lstm_pred, zs=6, c='r', label='Y0')
ax.scatter(x_pca, lstm_pred, zs=7, c='g', label='LSTM')
ax.scatter(x_pca, bilstm_pred, zs=8, c='b', label='BiLSTM')
ax.scatter(x_pca, y_test, zs=5.5, c='skyblue', label='Actual pH')
ax.scatter(x_pca, lasso_pred, zs=6.5, c='y', label='Lasso')
ax.scatter(x_pca, dt_pred, zs=7, c='m', label='DT')
ax.scatter(x_pca, ann_pred, zs=8, c='r', label='ANN')


# Set labels for axes
ax.set_xlabel('Input-data-points')
ax.set_ylabel('Predictions')
ax.set_zlabel('Algorithms')

# Display the legend
# ax.legend()
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Set x and y axis limits
ax.set_xlim([-2, 4])
ax.set_ylim([6.0, 8.5])

ax.view_init(15, 110)
# ax.view_init(5, 170)
# z-axis ^|v, xy angle <->
# 10-115

# Show the 3D scatter plot
plt.show()

# %% [markdown]
# ## 2D line plot live

# %%
# Values of two runs:
mse_vals = [
                model_acc_lasso,
                model_acc_dt,
                model_acc_ann,

                model_acc_lstm,
                model_acc_bilstm,
            ]

# %% [markdown]
# ## 2D line plot archive

# %%
# ASsigning names and creating mean array:
names = [
            'Lasso\nRegression',
            'Decision\nTree',
            'ANN',
            'LSTM',
            'Bi-LSTM'
        ]

# Values of two runs:
vals1 = [
            0.19576893353283545,
            0.18954301075268834,
            0.17560012137718314,
            0.23363526338119486,
            0.19352527551503568
        ]

vals2 = [
            0.1548082615622019,
            0.1400666666666666,
            0.1922316308897701,
            0.20942134988934477,
            0.15733696581746584
        ]

vals3 = [
            0.16593413082405184,
            0.1372177419354839,
            35.56075971121054,
            0.1799235669507418,
            0.16561007854297716
        ]

vals4 = []
for i in range(0,5):
    vals4.append((vals1[i] + vals2[i] + vals3[i])/3)

# %% [markdown]
# ## bar plot archive

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Vals3 contains MSE values and names contains algorithm names
mean_mse = np.mean(vals3)
std_dev_mse = np.std(vals3)

# Plotting
fig, ax = plt.subplots()

# Bar plot for MSE values with error bars
sns.barplot(x=names, y=vals3, errorbar='sd')
# sns.barplot(x=names, y=vals3, color='skyblue', errorbar='sd')

# Horizontal lines for Mean, Mean + Std Dev, Mean - Std Dev
ax.axhline(mean_mse, color='red', linestyle='--', label='Mean MSE')
ax.axhline(mean_mse + std_dev_mse, color='orange', linestyle='--', label='Mean + Std Dev')
ax.axhline(mean_mse - std_dev_mse, color='orange', linestyle='--', label='Mean - Std Dev')

plt.xlabel('Algorithm')
plt.ylabel('Mean Squared Error')
plt.title('Bar Plot: Algorithm vs. MSE with Deviation from Mean')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Place legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Vals3 contains MSE values and names contains algorithm names
mean_mse = np.mean(vals3)
std_dev_mse = np.std(vals3)

# Plotting
fig, ax = plt.subplots()

# Bar plot for MSE values with error bars
sns.barplot(x=names[0:2]+names[3:], y=vals3[0:2]+vals3[3:], errorbar='sd')
# sns.barplot(x=names, y=vals3, color='skyblue', errorbar='sd')

# Horizontal lines for Mean, Mean + Std Dev, Mean - Std Dev
ax.axhline(mean_mse, color='red', linestyle='--', label='Mean MSE')
ax.axhline(mean_mse + std_dev_mse, color='orange', linestyle='--', label='Mean + Std Dev')
ax.axhline(mean_mse - std_dev_mse, color='orange', linestyle='--', label='Mean - Std Dev')

plt.xlabel('Algorithm')
plt.ylabel('Mean Squared Error')
plt.title('Bar Plot: Algorithm vs. MSE with Deviation from Mean')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.yticks(np.arange(0, 1, 0.01))

# Place legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
